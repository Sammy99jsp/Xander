# %%
import pandas as pd
csv = pd.read_csv("./out/log.csv");
processed = pd.DataFrame({'steps': csv['steps'], 'avg_rew': csv['avg_rew'].ewm(alpha=0.1).mean(), 'episode_len': csv['last_10_ep_len'].ewm(alpha=0.1).mean() })
processed.plot(x="steps", y=["avg_rew", ], title="Average Reward")
# Out:
# <Axes: title={'center': 'Average Reward'}, xlabel='steps'>
